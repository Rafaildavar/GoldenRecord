# %%
import numpy as np

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ds_dirty_fin_202410041147.csv')
# Out:
# <ipython-input-2-84eb574b0b30>:2: DtypeWarning: Columns (18,19,20,25,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ds_dirty_fin_202410041147.csv')

# %% [markdown]
# 1. **client_id** — ID клиента
# 2. **client_first_name** — Имя клиента
# 3. **client_middle_name** — Отчество клиента
# 4. **client_last_name** — Фамилия клиента
# 5. **client_fio_full** — Полное ФИО клиента
# 6. **client_bday** — Дата рождения клиента
# 7. **client_bplace** — Место рождения клиента
# 8. **client_cityzen** — Гражданство клиента
# 9. **client_resident_cd** — Резидентский статус клиента
# 10. **client_gender** — Пол клиента
# 11. **client_marital_cd** — Семейное положение клиента
# 12. **client_graduate** — Уровень образования клиента
# 13. **client_child_cnt** — Количество детей у клиента
# 14. **client_mil_cd** — Воинский статус клиента
# 15. **client_zagran_cd** — Наличие загранпаспорта
# 16. **client_inn** — ИНН клиента
# 17. **client_snils** — СНИЛС клиента
# 18. **client_vip_cd** — VIP-статус клиента
# 19. **contact_vc** — Контакт в видеоконференциях
# 20. **contact_tg** — Контакт в Telegram
# 21. **contact_other** — Другие контакты
# 22. **contact_email** — Email клиента
# 23. **contact_phone** — Телефон клиента
# 24. **addr_region** — Регион проживания клиента
# 25. **addr_country** — Страна проживания клиента
# 26. **addr_zip** — Почтовый индекс клиента
# 27. **addr_street** — Улица проживания клиента
# 28. **addr_house** — Номер дома клиента
# 29. **addr_body** — Корпус клиента
# 30. **addr_flat** — Номер квартиры клиента
# 31. **addr_area** — Район проживания клиента
# 32. **addr_loc** — Населенный пункт клиента
# 33. **addr_city** — Город проживания клиента
# 34. **addr_reg_dt** — Дата регистрации по адресу
# 35. **addr_str** — Полный адрес клиента
# 36. **fin_rating** — Финансовый рейтинг клиента
# 37. **fin_loan_limit** — Лимит займа клиента
# 38. **fin_loan_value** — Сумма займа клиента
# 39. **fin_loan_debt** — Задолженность клиента по займу
# 40. **fin_loan_percent** — Процентная ставка займа клиента
# 41. **fin_loan_begin_dt** — Дата начала займа
# 42. **fin_loan_end_dt** — Дата окончания займа
# 43. **stream_favorite_show** — Любимое шоу клиента
# 44. **stream_duration** — Продолжительность просмотра клиентом
# 45. **create_date** — Дата создания записи
# 46. **update_date** — Дата обновления записи
# 47. **source_cd** — Источник данных о клиенте

# %%
df.head()
# Out:
#    client_id client_first_name client_middle_name client_last_name  \
# 0  596118586            Меджид          Кузарович          Евдунов
# 1  747208737            Мансыр         Хирсанович            Повод
# 2  625104053         НУРДИНБЕК          УВАЙСОВИЧ           БУРНАС
# 3  624196811             Афаят          Гордиевна     Бондажевская
# 4  177500487             Сахия           Фидаевна          Разуева
#
#                 client_fio_full client_bday  \
# 0      Евдунов Меджид Кузарович  1992-08-23
# 1       Повод Мансыр Хирсанович  1987-03-15
# 2    БУРНАС НУРДИНБЕК УВАЙСОВИЧ  1961-04-05
# 3  Бондажевская Афаят Гордиевна  1976-06-01
# 4        Разуева Сахия Фидаевна  1961-07-31
#
#                                        client_bplace client_cityzen  \
# 0  ДЕР. КИРГИНЦЕВО АРОМАШЕВСКОГО Р-НА ТЮМЕНСКОЙ ОБЛ.            RUS
# 1                                                NaN            NaN
# 2  СЕЛО ДИОРОВА ТЯЧЕВСКОГО РАЙОНА ЗАКАРПАТСКОЙ ОБ...            RUS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005530 entries, 0 to 1005529
# Data columns (total 47 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   client_id             1005530 non-null  int64
#  1   client_first_name     961051 non-null   object
#  2   client_middle_name    961073 non-null   object
#  3   client_last_name      961125 non-null   object
#  4   client_fio_full       998618 non-null   object
#  5   client_bday           1005488 non-null  object
#  6   client_bplace         874089 non-null   object
#  7   client_cityzen        874089 non-null   object
#  8   client_resident_cd    1005336 non-null  object
#  9   client_gender         1005336 non-null  object
#  10  client_marital_cd     1005336 non-null  object
#  11  client_graduate       529853 non-null   object
#  12  client_child_cnt      668479 non-null   float64
#  13  client_mil_cd         1005336 non-null  object
# ...

# %%
test_df = df

# %%
test_df = test_df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
# Out:
# <ipython-input-20-79cf7d60fc32>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   test_df = test_df.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# %%
test_df.head()
# Out:
#    client_id client_first_name client_middle_name client_last_name  \
# 0  596118586            меджид          кузарович          евдунов
# 1  747208737            мансыр         хирсанович            повод
# 2  625104053         нурдинбек          увайсович           бурнас
# 3  624196811             афаят          гордиевна     бондажевская
# 4  177500487             сахия           фидаевна          разуева
#
#                 client_fio_full client_bday  \
# 0      евдунов меджид кузарович  1992-08-23
# 1       повод мансыр хирсанович  1987-03-15
# 2    бурнас нурдинбек увайсович  1961-04-05
# 3  бондажевская афаят гордиевна  1976-06-01
# 4        разуева сахия фидаевна  1961-07-31
#
#                                        client_bplace client_cityzen  \
# 0  дер. киргинцево аромашевского р-на тюменской обл.            rus
# 1                                                NaN            NaN
# 2  село диорова тячевского района закарпатской об...            rus
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
test_df['client_gender'] = test_df['client_gender'].apply(lambda x: x if x in ["м", "ж"] else np.nan)
test_df['client_gender'] = test_df['client_gender'].replace("м", 1)
test_df['client_gender'] = test_df['client_gender'].replace("ж", 0)
# Out:
# <ipython-input-27-49a04e6e8a42>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df['client_gender'] = test_df['client_gender'].replace("ж", 0)

# %%
print(test_df["client_gender"].unique())
# Out:
# [ 1.  0. nan]

# %%
test_df['client_cityzen'] = test_df["client_cityzen"].apply(lambda x: x if isinstance(x, str) and len(x)==3 else np.nan)

# %%
print(test_df["client_cityzen"].unique())
# Out:
# ['rus' nan 'blr' 'aze' 'arm' 'tjk' 'mda' 'kgz' 'uzb']

# %%
test_df["client_bday"] = pd.to_datetime(test_df["client_bday"], errors="coerce")

# %%
test_df['client_resident_cd'] = test_df["client_resident_cd"].apply(lambda x: 1 if x=='д' else 0)

# %%
test_df["client_resident_cd"].unique()
# Out:
# array([1, 0])

# %%
test_df.head()
# Out:
#    client_id client_first_name client_middle_name client_last_name  \
# 0  596118586            меджид          кузарович          евдунов
# 1  747208737            мансыр         хирсанович            повод
# 2  625104053         нурдинбек          увайсович           бурнас
# 3  624196811             афаят          гордиевна     бондажевская
# 4  177500487             сахия           фидаевна          разуева
#
#                 client_fio_full client_bday  \
# 0      евдунов меджид кузарович  1992-08-23
# 1       повод мансыр хирсанович  1987-03-15
# 2    бурнас нурдинбек увайсович  1961-04-05
# 3  бондажевская афаят гордиевна  1976-06-01
# 4        разуева сахия фидаевна  1961-07-31
#
#                                        client_bplace client_cityzen  \
# 0  дер. киргинцево аромашевского р-на тюменской обл.            rus
# 1                                                NaN            NaN
# 2  село диорова тячевского района закарпатской об...            rus
# ...

# %%
test_df_copy = test_df[['client_first_name','client_middle_name','client_last_name',
                        'client_fio_full','client_snils','client_inn','contact_phone',
                        'contact_email','contact_tg','contact_other']].copy()

# %%
test_df_copy.head(10)
# Out:
#   client_first_name client_middle_name client_last_name  \
# 0            меджид          кузарович          евдунов
# 1            мансыр         хирсанович            повод
# 2         нурдинбек          увайсович           бурнас
# 3             афаят          гордиевна     бондажевская
# 4             сахия           фидаевна          разуева
# 5            аржана           наилович         чередник
# 6            аимкан        агургеновна            богач
# 7              арли               янис          помилов
# 8           магарам            тайевич             лыло
# 9            тойдык          чукановна            лехно
#
#                 client_fio_full  client_snils    client_inn    contact_phone  \
# 0      евдунов меджид кузарович  5.220320e+10  9.123435e+11  +7 926 226 7251
# 1       повод мансыр хирсанович           NaN           NaN  +7 923 794 1066
# 2    бурнас нурдинбек увайсович           NaN           NaN  +7 927 449 6708
# ...

# %%
test_df_copy['contact_phone'].value_counts()
# Out:
# contact_phone
# без срока доставки    194
# +7 915 132 5269         9
# +7 959 576 9562         9
# +7 913 295 9959         9
# +7 962 417 4628         9
#                      ...
# +7 995 477 2257         1
# +7 939 909 4835         1
# +7 936 777 5627         1
# +7 993 963 3548         1
# +7 900 543 8927         1
# Name: count, Length: 256731, dtype: int64

# %%
filtered_df = test_df_copy[test_df_copy["contact_phone"] == '+7 915 132 5269']
filtered_df
# Out:
#        client_first_name client_middle_name client_last_name  \
# 23962              хатия        миннишаевна           кургак
# 337057             хатия        миннишаевна           кургак
# 435233             хатия        миннишаевна           кургак
# 553606             хатия        миннишаевна           кургак
# 736674             хатия        миннишаевна           кургак
# 872580               NaN                NaN              NaN
# 873841               NaN                NaN              NaN
# 943798             хатия        миннишаевна           кургак
# 986815             хатия        миннишаевна           кургак
#
#                  client_fio_full  client_snils    client_inn    contact_phone  \
# 23962   кургак хатия миннишаевна           NaN           NaN  +7 915 132 5269
# 337057  кургак хатия миннишаевна  3.253887e+10  1.704093e+11  +7 915 132 5269
# 435233  кургак хатия миннишаевна  3.253887e+10  1.704093e+11  +7 915 132 5269
# ...
